# %% [markdown]
# # VARIABLES ALEATORIAS

# %%
#importar modulos
import pandas as pd
import numpy as np
import matplotlib.pyplot as pit

# %%
n=10000
a=0
b=1
#modulo 
data = np.random.uniform(a,b,n)

# %%
data
# Out:
# array([0.37287789, 0.29854844, 0.95643255, ..., 0.68500955, 0.87063343,
#        0.23176689])

# %%
#tipo de objeto, un arreglo de numpy
type (data)
# Out:
# numpy.ndarray

# %% [markdown]
# ## como gráficar nuestros datos

# %%
#longitud de la variable data
len(data)
# Out:
# 10000

# %%
t = range(len(data))

# %%
t
# Out:
# range(0, 10000)

# %%
len(t)
# Out:
# 10000

# %%
# %matplotlib inline

# %% [markdown]
# ### Por regiones te dice cuantos valores hay.

# %%
pit.hist(data)
# Out:
# (array([1025., 1005.,  965.,  933., 1000.,  975., 1069., 1003.,  979.,
#         1046.]),
#  array([7.29135158e-05, 1.00045164e-01, 2.00017415e-01, 2.99989666e-01,
#         3.99961917e-01, 4.99934168e-01, 5.99906419e-01, 6.99878669e-01,
#         7.99850920e-01, 8.99823171e-01, 9.99795422e-01]),
#  <a list of 10 Patch objects>)

# %%
#distribucion normal
data = np.random.randn(n)
x = range(1,n+1)

# %%
pit.plot(x, data)

# %%
#Para observar la distribucion normal (campana) con no se que normal estándar
pit.hist(data)
# Out:
# (array([1.400e+01, 1.120e+02, 6.340e+02, 1.954e+03, 3.029e+03, 2.611e+03,
#         1.273e+03, 3.160e+02, 5.500e+01, 2.000e+00]),
#  array([-3.78833424, -2.99531654, -2.20229885, -1.40928116, -0.61626346,
#          0.17675423,  0.96977193,  1.76278962,  2.55580731,  3.34882501,
#          4.1418427 ]),
#  <a list of 10 Patch objects>)

# %%
#datos ordenados
pit.plot(x, sorted(data))

# %%
errores = np.random.randn(n)

# %%
#desviación estándar (sigma)
sigma = 5

# %%
errores*=sigma

# %%
pit.hist(errores)
# Out:
# (array([  20.,  120.,  647., 1717., 2704., 2554., 1635.,  505.,   87.,
#           11.]), array([-18.03683311, -14.37332842, -10.70982374,  -7.04631905,
#          -3.38281436,   0.28069032,   3.94419501,   7.6076997 ,
#          11.27120438,  14.93470907,  18.59821376]), <a list of 10 Patch objects>)

# %%
#varianza (sigma^2)
np.var(errores)
# Out:
# 24.665439121781862

# %%
x = range(0,n)

# %%
a=0
b=1

# %%
len(x)
# Out:
# 10000

# %%
len(errores)
# Out:
# 10000

# %%
#Importar datos
url_datos = "http://winterolympicsmedals.com/medals.csv"

# %%
models_data = pd.read_csv(url_datos)

# %%
models_data.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
type(models_data)
# Out:
# pandas.core.frame.DataFrame

# %%
models_data.shape
# Out:
# (2311, 8)

# %%
models_data.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'NOC', 'Event', 'Event gender',
#        'Medal'],
#       dtype='object')

# %%
models_data.columns.values
# Out:
# array(['Year', 'City', 'Sport', 'Discipline', 'NOC', 'Event',
#        'Event gender', 'Medal'], dtype=object)
